# %%
import pandas as pd
import pyarrow

# %%
DoS1_Thursday=pd.read_parquet("../datasets/DoS1-Thursday-15-02-2018_TrafficForML_CICFlowMeter.parquet")

# %%
DoS2_Friday=pd.read_parquet("../datasets/DoS2-Friday-16-02-2018_TrafficForML_CICFlowMeter.parquet")

# %%
DDoS1_Tuesday=pd.read_parquet("../datasets/DDoS1-Tuesday-20-02-2018_TrafficForML_CICFlowMeter.parquet")

# %%
DDoS2_Wednesday=pd.read_parquet("../datasets/DDoS2-Wednesday-21-02-2018_TrafficForML_CICFlowMeter.parquet")

# %%
data = pd.concat([, df2], ignore_index=True)

# %%
# print(data.columns.tolist())

# %%
print(data.dtypes)
# Out:
# Protocol                        int8
# Flow Duration                  int32
# Total Fwd Packets              int16
# Total Backward Packets         int16
# Fwd Packets Length Total       int32
#                               ...
# Idle Mean                    float32
# Idle Std                     float32
# Idle Max                       int32
# Idle Min                       int32
# Label                       category
# Length: 78, dtype: object

# %%
print(data['Label'].unique())
# Out:
# ['Benign', 'DoS attacks-GoldenEye', 'DoS attacks-Slowloris']
# Categories (3, str): ['Benign', 'DoS attacks-GoldenEye', 'DoS attacks-Slowloris']

# %%
dos_labels = ['Benign', 'DoS attacks-GoldenEye', 'DoS attacks-Slowloris']

df = df[df['Label'].isin(dos_labels)]
print(df['Label'].value_counts())
# Out:
# Label
# Benign                   743498
# DoS attacks-GoldenEye     41406
# DoS attacks-Slowloris      9908
# Name: count, dtype: int64
