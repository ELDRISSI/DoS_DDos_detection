# %%
# Cell 1: Imports and Configuration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import os

# Modeling and Evaluation Metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, 
    confusion_matrix, classification_report, roc_auc_score, roc_curve
)
from sklearn.preprocessing import label_binarize

# Set professional visualization aesthetics
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ Cell 1 Complete: All libraries imported successfully.")
# Out:
# ✅ Cell 1 Complete: All libraries imported successfully.

# %%
# Cell 2: Load Ready-to-Use Balanced Parquet Files
train_path = '../ready_project_dataset/train_ready.parquet'
test_path = '../ready_project_dataset/test_ready.parquet'

print("⏳ Loading pre-processed ready datasets...")
train_df = pd.read_parquet(train_path)
test_df = pd.read_parquet(test_path)

# Separate features (X) from class target labels (y)
X_train = train_df.drop(columns=['Label'])
y_train = train_df['Label']

X_test = test_df.drop(columns=['Label'])
y_test = test_df['Label']

print("✅ Cell 2 Complete.")
print(f"-> Training Set Features Shape (Balanced): {X_train.shape}")
print(f"-> Testing Set Features Shape (Real Distribution): {X_test.shape}")
print("\n📊 Class Counts in Balanced Training Set:")
print(Counter(y_train))
print("\n📊 Class Counts in Original Test Set:")
print(Counter(y_test))
# Out:
# ⏳ Loading pre-processed ready datasets...
# ✅ Cell 2 Complete.
# -> Training Set Features Shape (Balanced): (640000, 74)
# -> Testing Set Features Shape (Real Distribution): (90620, 74)
#
# 📊 Class Counts in Balanced Training Set:
# Counter({'DoS attacks-Hulk': 80000, 'DoS attacks-GoldenEye': 80000, 'DDOS attack-HOIC': 80000, 'DDoS attacks-LOIC-HTTP': 80000, 'Benign': 80000, 'DoS attacks-Slowloris': 80000, 'DDOS attack-LOIC-UDP': 80000, 'DoS attacks-SlowHTTPTest': 80000})
#
# 📊 Class Counts in Original Test Set:
# Counter({'DoS attacks-Hulk': 20000, 'Benign': 20000, 'DDOS attack-HOIC': 20000, 'DDoS attacks-LOIC-HTTP': 20000, 'DoS attacks-GoldenEye': 8281, 'DoS attacks-Slowloris': 1982, 'DDOS attack-LOIC-UDP': 346, 'DoS attacks-SlowHTTPTest': 11})

# %%
# Cell 3: Train Upgraded Random Forest Model
print("Initializing Upgraded Random Forest Classifier...")

rf_model = RandomForestClassifier(
    n_estimators=150,                 # Increased for ensemble stability
    max_depth=25,                     # Expanded safely for deep non-linear patterns
    min_samples_split=4,              # Controls split quality
    min_samples_leaf=2,               # Prevents noise leaf capture
    oob_score=True,                   # Enables out-of-bag validation score
    random_state=42,                
    n_jobs=-1,                        # Accelerates training using all CPU cores
    verbose=1                         # Displays live processing progress
)

print("\n⏳ Training the model (learning genuine behavioral characteristics)...")
rf_model.fit(X_train, y_train)

print(f"\n📈 Out-of-Bag (OOB) Validation Score: {rf_model.oob_score_:.4f}")

# Generate Predictions for evaluations
print("\nGenerating predictions on unseen Test Set...")
y_pred = rf_model.predict(X_test)
y_prob = rf_model.predict_proba(X_test) 

print("✅ Cell 3 Complete: Model Trained and Predictions Generated!")
# Out:
# Initializing Upgraded Random Forest Classifier...
#
# ⏳ Training the model (learning genuine behavioral characteristics)...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   57.7s finished
# 📈 Out-of-Bag (OOB) Validation Score: 0.9980
#
# Generating predictions on unseen Test Set...
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 150 out of 150 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# ✅ Cell 3 Complete: Model Trained and Predictions Generated!
# [Parallel(n_jobs=8)]: Done 150 out of 150 | elapsed:    0.3s finished

# %%
# Cell 4: Performance Evaluation Metrics
# We keep macro averages so that small, high-risk attack categories hold equal weight
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro', zero_division=0)
recall = recall_score(y_test, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_test, y_pred, average='macro', zero_division=0)

print("================ GLOBAL PERFORMANCE METRICS ================")
print(f"Accuracy:  {accuracy:.5f}")
print(f"Precision: {precision:.5f} (Macro Average)")
print(f"Recall:    {recall:.5f} (Macro Average)")
print(f"F1-Score:  {f1:.5f} (Macro Average)")
print("=============================================================")

print("\n================ DETAILED CLASS PERFORMANCE ================")
print(classification_report(y_test, y_pred, zero_division=0))
print("================================================================")
print("✅ Cell 4 Complete.")
# Out:
# ================ GLOBAL PERFORMANCE METRICS ================
# Accuracy:  0.99642
# Precision: 0.98083 (Macro Average)
# Recall:    0.99792 (Macro Average)
# F1-Score:  0.98906 (Macro Average)
# ...
#
# ================ DETAILED CLASS PERFORMANCE ================
#                           precision    recall  f1-score   support
#
#                   Benign       1.00      0.99      0.99     20000
#         DDOS attack-HOIC       0.99      1.00      1.00     20000
#     DDOS attack-LOIC-UDP       0.95      1.00      0.97       346
#   DDoS attacks-LOIC-HTTP       1.00      1.00      1.00     20000
#    DoS attacks-GoldenEye       1.00      1.00      1.00      8281
#         DoS attacks-Hulk       1.00      1.00      1.00     20000
# DoS attacks-SlowHTTPTest       0.92      1.00      0.96        11
#    DoS attacks-Slowloris       1.00      1.00      1.00      1982
#
#                 accuracy                           1.00     90620
# ...

# %%
# Cell 5: Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred, labels=rf_model.classes_)

plt.figure(figsize=(11, 9))
sns.heatmap(
    cm, 
    annot=True, 
    fmt='d', 
    cmap='Blues', 
    xticklabels=rf_model.classes_, 
    yticklabels=rf_model.classes_
)
plt.title("Confusion Matrix: True vs. Predicted Attack Categories", fontsize=14, pad=15)
plt.ylabel('True Attack Category', fontsize=12)
plt.xlabel('Predicted Attack Category', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

print("✅ Cell 5 Complete.")
# Out:
# ✅ Cell 5 Complete.

# %%
# Cell 6: Multi-Class ROC Curves (One-vs-Rest)
classes = list(rf_model.classes_)
n_classes = len(classes)

# Binarize labels to evaluate true/false positive rate tradeoffs over shifting thresholds
y_test_bin = label_binarize(y_test, classes=classes)

plt.figure(figsize=(11, 8))

for i, class_label in enumerate(classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_prob[:, i])
    class_auc = roc_auc_score(y_test_bin[:, i], y_prob[:, i])
    plt.plot(fpr, tpr, lw=2, label=f'{class_label} (AUC = {class_auc:.4f})')

plt.plot([0, 1], [0, 1], color='navy', lw=1.5, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=11)
plt.ylabel('True Positive Rate', fontsize=11)
plt.title('Multi-Class ROC Curves (One-vs-Rest Evaluation)', fontsize=14, pad=15)
plt.legend(loc="lower right", fontsize=10)
plt.tight_layout()
plt.show()

print("✅ Cell 6 Complete.")
# Out:
# ✅ Cell 6 Complete.

# %%
# Cell 7: Top 15 Most Important Network Features
importances = rf_model.feature_importances_
feature_names = X_train.columns
rf_importances = pd.Series(importances, index=feature_names).sort_values(ascending=False)

plt.figure(figsize=(12, 6))
# FIX: Explicitly assign y to hue and set legend=False to clear out Deprecation Warnings
sns.barplot(
    x=rf_importances.head(15).values, 
    y=rf_importances.head(15).index, 
    palette="mako", 
    hue=rf_importances.head(15).index, 
    legend=False
)
plt.title("Top 15 Most Important Network Flow Features (Data Leakage Resolved)", fontsize=14, pad=15)
plt.xlabel("Importance Score Contribution", fontsize=12)
plt.ylabel("Network Feature Name", fontsize=12)
plt.tight_layout()
plt.show()

print("✅ Cell 7 Complete.")
# Out:
# ✅ Cell 7 Complete.

# %%
# Cell 8: Training vs Test Accuracy Gap Analysis
print("⏳ Calculating training dataset baseline accuracy...")
train_acc = rf_model.score(X_train, y_train)
test_acc = accuracy_score(y_test, y_pred)
gap = train_acc - test_acc

print("\n================ GENERALIZATION ACCURACY GAP ================")
print(f"📊 Training Set Accuracy : {train_acc * 100:.4f}%")
print(f"📊 Unseen Test Accuracy  : {test_acc * 100:.4f}%")
print(f"📉 Generalization Gap    : {gap * 100:.4f}%")
print("=============================================================")

if gap > 0.04:
    print("⚠️ Warning: Significant variance gap detected! The model might be adapting slightly too closely to training records.")
else:
    print("✅ Healthy Baseline: The model transitions robustly from training data to completely unseen network behaviors.")
# Out:
# ⏳ Calculating training dataset baseline accuracy...
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 150 out of 150 | elapsed:    2.6s finished
# ================ GENERALIZATION ACCURACY GAP ================
# 📊 Training Set Accuracy : 99.8533%
# 📊 Unseen Test Accuracy  : 99.6425%
# 📉 Generalization Gap    : 0.2108%
# ...
# ✅ Healthy Baseline: The model transitions robustly from training data to completely unseen network behaviors.

# %%
# Cell 9: Learning Curves Calculation and Plotting
from sklearn.model_selection import learning_curve

print("⏳ Computing Learning Curves (retraining cross-validations at incremental size intervals)...")

# We use 3 CV folds inside learning_curve to accelerate runtime while keeping math robust
train_sizes, train_scores, val_scores = learning_curve(
    estimator=rf_model, 
    X=X_train, 
    y=y_train, 
    train_sizes=np.linspace(0.1, 1.0, 5), 
    cv=3, 
    n_jobs=-1,
    scoring='accuracy'
)

# Calculate means and standard deviations
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
val_mean = np.mean(val_scores, axis=1)
val_std = np.std(val_scores, axis=1)

# Generate Chart
plt.figure(figsize=(11, 6))
plt.plot(train_sizes, train_mean, 'o-', color="#d9534f", label="Training Score Evaluation", lw=2)
plt.plot(train_sizes, val_mean, 'o-', color="#5cb85c", label="Cross-Validation Holdout Score", lw=2)

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1, color="#d9534f")
plt.fill_between(train_sizes, val_mean - val_std, val_mean + val_std, alpha=0.1, color="#5cb85c")

plt.title("Random Forest Learning Curve (Convergence Check)", fontsize=14, pad=15)
plt.xlabel("Volume of Training Examples Processed", fontsize=12)
plt.ylabel("Accuracy Performance Metric", fontsize=12)
plt.legend(loc="lower right", fontsize=11)
plt.tight_layout()
plt.show()

print("✅ Cell 9 Complete.")
# Out:
# ⏳ Computing Learning Curves (retraining cross-validations at incremental size intervals)...
# ✅ Cell 9 Complete.

# %%
# Cell 10: Feature Importance Leakage Audit
importances = rf_model.feature_importances_
feature_names = X_train.columns
rf_importances = pd.Series(importances, index=feature_names).sort_values(ascending=False)

print("=================== FEATURE IMPORTANCE AUDIT ===================")
print("🏆 Top 5 Most Dominant Network Features:")
for idx, (feat, val) in enumerate(rf_importances.head(5).items()):
    print(f"  {idx+1}. {feat:<28} -> {val*100:.2f}% Contribution")

print("\n🚨 BLACKLIST LEAKAGE SCAN:")
blacklist = ['Dst Port', 'Protocol', 'Timestamp', 'Src IP', 'Dst IP', 'Init Fwd Win Bytes', 'Init Bwd Win Bytes']
leaks_found = [feat for feat in blacklist if feat in X_train.columns]

if leaks_found:
    print(f"❌ CRITICAL EXPOSURE: High-risk columns still found in memory: {leaks_found}")
    print("⚠️ Re-run your updated Cell 2 cleanup sequence to filter out these structural elements.")
else:
    print("✅ CLEAN: No tracking signatures or hardcoded configuration parameters identified.")

# Check for single-feature dominance anomalies
if rf_importances.iloc[0] > 0.50:
    print(f"\n⚠️ Risk Warning: Feature '{rf_importances.index[0]}' controls over {rf_importances.iloc[0]*100:.1f}% of tree split choices.")
    print("   Ensure this specific metric naturally translates to real-world infrastructure variants.")
else:
    print("\n✅ Balanced Structure: Tree structures distribute splits organically across independent mathematical markers.")
print("================================================================")
# Out:
# =================== FEATURE IMPORTANCE AUDIT ===================
# 🏆 Top 5 Most Dominant Network Features:
#   1. Fwd Seg Size Min             -> 8.56% Contribution
#   2. Fwd Header Length            -> 5.56% Contribution
#   3. Flow Duration                -> 4.68% Contribution
#   4. Flow IAT Max                 -> 4.66% Contribution
#   5. Fwd Packets/s                -> 4.22% Contribution
#
# 🚨 BLACKLIST LEAKAGE SCAN:
# ✅ CLEAN: No tracking signatures or hardcoded configuration parameters identified.
#
# ✅ Balanced Structure: Tree structures distribute splits organically across independent mathematical markers.
# ...

# %%
# Cell 11: Stratified 5-Fold Cross-Validation on a Controlled Stratified Slice
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.model_selection import train_test_split

print("⏳ Isolating stratified evaluation subset to accelerate validation processing...")
target_cv_size = min(30000, len(X_train))

if len(X_train) > target_cv_size:
    # Use train_test_split purely to sample a clean, stratified percentage subset
    _, X_cv_sub, _, y_cv_sub = train_test_split(
        X_train, y_train, test_size=(target_cv_size / len(X_train)), stratify=y_train, random_state=42
    )
    print(f"-> Optimization: Processing 5-fold CV on isolated {target_cv_size} row stratified layout.")
else:
    X_cv_sub, y_cv_sub = X_train, y_train

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(rf_model, X_cv_sub, y_cv_sub, cv=skf, n_jobs=-1, scoring='accuracy')

print("\n================ STRATIFIED 5-FOLD CV RESULTS ================")
for fold_idx, score in enumerate(cv_scores):
    print(f" 🟩 Fold {fold_idx + 1} Run Accuracy: {score * 100:.4f}%")
print("--------------------------------------------------------------")
print(f" 📈 Combined Average Accuracy : {cv_scores.mean() * 100:.4f}%")
print(f" 📉 Standard Deviation Variance: +/- {cv_scores.std() * 100:.4f}%")
print("==============================================================")

if cv_scores.std() > 0.02:
    print("⚠️ Warning: Higher variance across folds implies structural variance sensitive to specific subsets.")
else:
    print("✅ Model Stability Verified: Minimal scoring deviation across folds confirms generalizable metrics.")
# Out:
# ⏳ Isolating stratified evaluation subset to accelerate validation processing...
# -> Optimization: Processing 5-fold CV on isolated 30000 row stratified layout.
#
# ================ STRATIFIED 5-FOLD CV RESULTS ================
#  🟩 Fold 1 Run Accuracy: 99.7500%
#  🟩 Fold 2 Run Accuracy: 99.7833%
#  🟩 Fold 3 Run Accuracy: 99.7333%
#  🟩 Fold 4 Run Accuracy: 99.7000%
#  🟩 Fold 5 Run Accuracy: 99.7333%
# --------------------------------------------------------------
#  📈 Combined Average Accuracy : 99.7400%
#  📉 Standard Deviation Variance: +/- 0.0271%
# ...
# ✅ Model Stability Verified: Minimal scoring deviation across folds confirms generalizable metrics.

# %%
# Cell 12: Interactive Live Inference Engine (Fixed for String Labels)
def predict_live_flow(model, feature_template):
    """
    Simulates a live IDS sensor. Prompts for key features, 
    fills background metrics with training medians, and predicts the class.
    """
    print("\n" + "="*50)
    print("🛡️  LIVE NETWORK FLOW CLASSIFIER SIMULATOR  🛡️")
    print("="*50)
    print("Please extract these 5 metrics from your 2017 dataset row:")
    
    # Create a copy of the median training row to use as our base template
    live_sample = feature_template.copy()
    
    # Define the top driving features we want to manually test
    key_features = [
        ('Fwd Packet Length Max', 'Max size of packets in forward direction (e.g., 0 to 5000+)'),
        ('Fwd Seg Size Min',      'Minimum segment size observed forward (often 20, 32, or 40)'),
        ('Avg Fwd Segment Size',  'Average size of forward segments'),
        ('Fwd Packet Length Mean','Mean packet length in forward direction'),
        ('Fwd Packet Length Std', 'Standard deviation of forward packet lengths')
    ]
    
    # Collect manual inputs safely
    for feat_name, desc in key_features:
        while True:
            try:
                user_val = input(f"🔹 {feat_name} ({desc}): ")
                live_sample[feat_name] = float(user_val)
                break
            except ValueError:
                print("❌ Invalid number. Please enter a valid integer or decimal value.")
    
    # Convert single row dictionary into a 1-row DataFrame matching training layout
    input_df = pd.DataFrame([live_sample])
    
    # Run through the Random Forest
    detected_class = model.predict(input_df)[0]
    pred_probs = model.predict_proba(input_df)[0]
    
    # Read classes directly from the model to map probabilities accurately
    model_classes = list(model.classes_)
    class_idx = model_classes.index(detected_class)
    confidence = pred_probs[class_idx] * 100
    
    print("\n" + "="*50)
    print("🔍 ENGINE ANALYSIS COMPLETED")
    print("="*50)
    if str(detected_class).lower() == "benign" or detected_class == 0:
        print(f"🟩 STATUS: SAFE TRAFFIC")
        print(f"   The flow matches standard human behavior profile.")
    else:
        print(f"🚨 STATUS: MALICIOUS ANOMALY DETECTED!")
        print(f"   Classification: [ {detected_class} ]")
        
    print(f"   Model Confidence: {confidence:.2f}%")
    print("-"*50)
    print("📊 Class Probability Breakdown:")
    for idx, name in enumerate(model_classes):
        print(f"   • {str(name):<26} : {pred_probs[idx]*100:>6.2f}%")
    print("="*50 + "\n")

# %%
# Cell 13: Execute Live Interactive Query
# Generate a median row template from your actual training features
training_median_profile = X_train.median().to_dict()

# Run the prompt engine (no manual target names list required anymore!)
predict_live_flow(rf_model, training_median_profile)
# Out:
# ...
# 🛡️  LIVE NETWORK FLOW CLASSIFIER SIMULATOR  🛡️
# ...
# Please extract these 5 metrics from your 2017 dataset row:
# 🔹 Fwd Packet Length Max (Max size of packets in forward direction (e.g., 0 to 5000+)):  1460
# 🔹 Fwd Seg Size Min (Minimum segment size observed forward (often 20, 32, or 40)):  32
# 🔹 Avg Fwd Segment Size (Average size of forward segments):  1460
# 🔹 Fwd Packet Length Mean (Mean packet length in forward direction):  1460
# 🔹 Fwd Packet Length Std (Standard deviation of forward packet lengths):  0.0
# ...
# 🔍 ENGINE ANALYSIS COMPLETED
# ...
# 🟩 STATUS: SAFE TRAFFIC
#    The flow matches standard human behavior profile.
#    Model Confidence: 60.38%
# --------------------------------------------------
# 📊 Class Probability Breakdown:
#    • Benign                     :  60.38%
#    • DDOS attack-HOIC           :   0.00%
#    • DDOS attack-LOIC-UDP       :   0.67%
#    • DDoS attacks-LOIC-HTTP     :   0.67%
#    • DoS attacks-GoldenEye      :   3.02%
# ...

# %%
# Cell 14: Pure Blind 2017 CSV Row Inference Engine


# 1. Load the 2017 CSV Dataset
csv_filename = '../ready_project_dataset/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv'
print(f"📦 Loading {csv_filename}... Please wait (this may take a moment).")

# Load the file
df_2017_csv = pd.read_csv(csv_filename)

# Standardize column headers by stripping trailing or hidden whitespaces
df_2017_csv.columns = df_2017_csv.columns.str.strip()
print(f"✅ Loaded successfully! Total rows available for testing: {len(df_2017_csv)}")


def predict_blind_csv_row(model, df_csv, X_train_columns):
    """
    Prompts for a row number, extracts the entire authentic row, aligns its 
    2017 schema to match the 2018 model columns, and performs blind inference.
    """
    # 2. Secure valid row index from user
    while True:
        try:
            user_input = input(f"\n🔹 Enter a 2017 row index to test (0 to {len(df_csv) - 1}): ")
            row_idx = int(user_input)
            if 0 <= row_idx < len(df_csv):
                break
            else:
                print(f"❌ Out of range! Enter a number between 0 and {len(df_csv) - 1}.")
        except ValueError:
            print("❌ Invalid input. Please enter a valid whole number.")
            
    # 3. Extract the raw row as a dictionary
    raw_row = df_csv.iloc[row_idx].to_dict()
    
    # Helper utility to strip non-alphanumeric characters and lowercase for flexible matching
    def normalize_string(text):
        return "".join(c for c in str(text).lower() if c.isalnum())
    
    # Comprehensive dictionary mapping shortened 2018 column headers to long 2017 headers
    alias_dictionary = {
        'dstport': ['destinationport'],
        'totfwdpkts': ['totalfwdpackets'],
        'totbwdpkts': ['totalbackwardpackets'],
        'totlenfwdpkts': ['totallengthoffwdpackets'],
        'totlenbwdpkts': ['totallengthofbwdpackets'],
        'fwdpktlenmax': ['fwdpacketlengthmax'],
        'fwdpktlenmin': ['fwdpacketlengthmin'],
        'fwdpktlenmean': ['fwdpacketlengthmean'],
        'fwdpktlenstd': ['fwdpacketlengthstd'],
        'bwdpktlenmax': ['bwdpacketlengthmax'],
        'bwdpktlenmin': ['bwdpacketlengthmin'],
        'bwdpktlenmean': ['bwdpacketlengthmean'],
        'bwdpktlenstd': ['bwdpacketlengthstd'],
        'flowbytss': ['flowbytess'],
        'flowpktss': ['flowpacketss'],
        'fwdpktss': ['fwdpacketss'],
        'bwdpktss': ['bwdpacketss'],
        'pktlenmin': ['minpacketlength'],
        'pktlenmax': ['maxpacketlength'],
        'pktlenmean': ['packetlengthmean'],
        'pktlenstd': ['packetlengthstd'],
        'pktlenvar': ['packetlengthvariance'],
        'fwdsegsizeavg': ['avgfwdsegmentsize'],
        'bwdsegsizeavg': ['avgbwdsegmentsize'],
        'initfwdwinbytes': ['initwinbytesforward', 'init_win_bytes_forward'],
        'initbwdwinbytes': ['initwinbytesbackward', 'init_win_bytes_backward'],
        'actdatapktfwd': ['actdatapktfwd', 'act_data_pkt_fwd'],
        'fwdsegsizemin': ['minsegsizeforward', 'min_seg_size_forward']
    }
    
    # Clean up pandas auto-generated duplicate suffixes (e.g. 'Fwd Header Length.1')
    normalized_csv_data = {}
    for col_name, val in raw_row.items():
        base_name = col_name.split('.')[0] if '.' in col_name else col_name
        normalized_csv_data[normalize_string(base_name)] = val

    # 4. Reconstruct the row matching the exact feature order of X_train
    aligned_sample = {}
    for model_col in X_train_columns:
        norm_model = normalize_string(model_col)
        
        # Scenario A: Direct or case-insensitive name match
        if norm_model in normalized_csv_data:
            aligned_sample[model_col] = normalized_csv_data[norm_model]
        # Scenario B: Match via shortened name abbreviation mapping
        elif norm_model in alias_dictionary:
            matched_val = 0.0
            for csv_alias in alias_dictionary[norm_model]:
                if csv_alias in normalized_csv_data:
                    matched_val = normalized_csv_data[csv_alias]
                    break
            aligned_sample[model_col] = matched_val
        # Scenario C: Default missing columns safely to zero
        else:
            aligned_sample[model_col] = 0.0
            
    # 5. Typecast features to floating points and handle missing values or infinity on the fly
    for col, val in aligned_sample.items():
        try:
            float_val = float(val)
            if np.isnan(float_val) or np.isinf(float_val):
                aligned_sample[col] = 0.0
            else:
                aligned_sample[col] = float_val
        except (ValueError, TypeError):
            aligned_sample[col] = 0.0
            
    # Convert dictionary into a 1-row DataFrame structured exactly like training layout
    input_df = pd.DataFrame([aligned_sample])[X_train_columns]
    
    # 6. Execute Blind Model Inference (No Label reading permitted)
    detected_class = model.predict(input_df)[0]
    pred_probs = model.predict_proba(input_df)[0]
    
    model_classes = list(model.classes_)
    class_idx = model_classes.index(detected_class)
    confidence = pred_probs[class_idx] * 100
    
    # 7. Print the Results
    print("\n" + "="*50)
    print(f"🛡️  BLIND NETWORK FLOW MODEL PREDICTION REPORT")
    print("="*50)
    print(f" 🔹 Row Selected     : Index {row_idx}")
    print(f" 🔹 Model Decision   : {detected_class}")
    print(f" 🔹 Detection Power  : {confidence:.2f}% Confidence")
    print("="*50)
    
    if str(detected_class).lower() == "benign" or detected_class == 0:
        print(" 🟩 ALERT STATUS: TRAFFIC SEEMS CLEAR / SAFE")
    else:
        print(" 🚨 ALERT STATUS: MALICIOUS ACTIVITY FLAGGED!")
        
    print("-"*50)
    print(" 📊 Full Probability Distribution Matrix:")
    for idx, name in enumerate(model_classes):
        print(f"   • {str(name):<26} : {pred_probs[idx]*100:>6.2f}%")
    print("="*50 + "\n")

# Run the blind prompt application using your model and training shape
predict_blind_csv_row(rf_model, df_2017_csv, X_train.columns)
# Out:
# 📦 Loading ../ready_project_dataset/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv... Please wait (this may take a moment).
# ✅ Loaded successfully! Total rows available for testing: 225745
# 🔹 Enter a 2017 row index to test (0 to 225744):  82032
# ...
# 🛡️  BLIND NETWORK FLOW MODEL PREDICTION REPORT
# ...
#  🔹 Row Selected     : Index 82032
#  🔹 Model Decision   : Benign
#  🔹 Detection Power  : 90.67% Confidence
# ...
#  🟩 ALERT STATUS: TRAFFIC SEEMS CLEAR / SAFE
# --------------------------------------------------
#  📊 Full Probability Distribution Matrix:
#    • Benign                     :  90.67%
#    • DDOS attack-HOIC           :   0.00%
#    • DDOS attack-LOIC-UDP       :   0.00%
#    • DDoS attacks-LOIC-HTTP     :   4.67%
#    • DoS attacks-GoldenEye      :   2.00%
#    • DoS attacks-Hulk           :   2.67%
#    • DoS attacks-SlowHTTPTest   :   0.00%
#    • DoS attacks-Slowloris      :   0.00%
# ...
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# ...
